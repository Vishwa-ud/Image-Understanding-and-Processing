# %% [markdown]
# ### Import Libraries

# %%
import cv2 as cv
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read an image

# %%
img1 = cv2.imread('D:/Education/Image-Understanding-and-Processing/Lab1/1.jpg',1)#path #flag
cv2.imshow("Image", img1)#windowname #image
cv2.waitKey()#show image
cv2.destroyAllWindows()

# %%
img2 = cv2.imread('D:/Education/Image-Understanding-and-Processing/Lab1/1.jpg',0)#path #flag
cv2.imshow("Image", img2)#windowname #image
cv2.waitKey()#show image
cv2.destroyAllWindows()

# %%
img3 = cv2.imread('D:/Education/Image-Understanding-and-Processing/Lab1/1.jpg',-1)#path #flag
cv2.imshow("Image", img3)#windowname #image
cv2.waitKey()#show image
cv2.destroyAllWindows()

# %%
image = cv2.imread('D:/Education/Image-Understanding-and-Processing/Lab1/1.jpg',cv2.IMREAD_COLOR)#path #flag
cv2.imshow("Image", image)#windowname #image
cv2.waitKey()#show image
cv2.destroyAllWindows()

# %%
image = cv2.imread('D:/Education/Image-Understanding-and-Processing/Lab1/1.jpg',cv2.IMREAD_GRAYSCALE)#path #flag
cv2.imshow("Image", image)#windowname #image
cv2.waitKey()#show image
cv2.destroyAllWindows()

# %%
image = cv2.imread('D:/Education/Image-Understanding-and-Processing/Lab1/1.jpg',cv2.IMREAD_UNCHANGED)#path #flag
cv2.imshow("Image", image)#windowname #image
cv2.waitKey()#show image
cv2.destroyAllWindows()

# %% [markdown]
# ## How to save an image

# %%
# Save the grayscale image
status = cv2.imwrite('D:/Education/Image-Understanding-and-Processing/Lab1/1_gray.jpg', image)  # Saves the image as '1_gray.jpg'
print("Grayscale image saved successfully.",status)
# Out:
# Grayscale image saved successfully. True

# %% [markdown]
# ## To access pixel values

# %%
image = cv2.imread('1.jpg',1)
px = image[50,100]
print(px)#display 3 chanels
# Out:
# [ 22 208 248]

# %% [markdown]
# ## Manipulate colors

# %%
image[50,100] = [0, 0, 255]
print(image[50, 100])
# Out:
# [  0   0 255]

# %% [markdown]
# ## To access image properties

# %%
image = cv2.imread('1.jpg',1)
print(image.shape)#size #channels
print(image.size)#access pixel values
print(image.dtype)
# Out:
# (225, 225, 3)
# 151875
# uint8

# %% [markdown]
# # Display all images at once

# %%
fig,ax = plt.subplots(1,3, figsize = (15, 15))
ax[0].imshow(cv.cvtColor(img1, cv.COLOR_BGR2RGB))
ax[0].axis('on')
ax[1].imshow(cv.cvtColor(img2, cv.COLOR_BGR2RGB))
ax[1].axis('off')
ax[2].imshow(cv.cvtColor(img3, cv.COLOR_BGR2RGB))
ax[2].axis('on')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %%
fig,ax = plt.subplots(3,1, figsize = (15, 15))
ax[0].imshow(cv.cvtColor(img1, cv.COLOR_BGR2RGB))
ax[0].axis('on')
ax[1].imshow(cv.cvtColor(img2, cv.COLOR_BGR2RGB))
ax[1].axis('on')
ax[2].imshow(cv.cvtColor(img3, cv.COLOR_BGR2RGB))
ax[2].axis('on')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %%
plt.imshow(cv.cvtColor(img1, cv.COLOR_BGR2RGB))
plt.axis('on')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %%
status = cv.imwrite('flower.jpg', img2)
print(status)
# Out:
# True

# %% [markdown]
# # Enlarge the image

# %%
image[50,100] = [0, 0, 255]

# enlarge the image
from matplotlib.pyplot import figure
figure(figsize=(10, 10))

plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
plt.axis('on')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %% [markdown]
# # Access image properties

# %%
image = cv2.imread('1.jpg',1)
print(image.shape)
print(image.size)
print(image.dtype)
# Out:
# (225, 225, 3)
# 151875
# uint8

# %%
image = cv2.imread('1.jpg',0)
print(image.shape)
print(image.size)
print(image.dtype)
# Out:
# (225, 225)
# 50625
# uint8

# %%
image = cv2.imread('1.jpg',1)
cv.imshow('Original Image', image)

imgGray = cv2.imread('1.jpg',0)
cv.imshow('Gray Image', imgGray)

res, binary = cv.threshold(imgGray, 120, 255, cv.THRESH_BINARY)
cv.imshow('Binary Image', binary)

print(res)

cv.waitKey()
cv.destroyAllWindows()
# Out:
# 120.0
